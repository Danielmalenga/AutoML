# %%
# ============================================================
# AutoGluon - CICIoT2023
# Classificação com dataset em C:\Dataset\CSV
# ============================================================
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

from autogluon.tabular import TabularPredictor

# %%
# ============================================================
# 1. Configurações principais
# ============================================================

DATASET_DIR = r"C:\Dataset\CSV"
RESULTS_DIR = r"C:\Dataset\Resultados\AutoGluon"

os.makedirs(RESULTS_DIR, exist_ok=True)
model_name = 'autogluon' # Define o modelo que será utilizado
device = 'cpu' #Define o processador do computador e não a GPU
min_samples_per_class = 5 #Define o mínimo de amostras por classe
n_classes = 2 #Define o número de classes de classificação

#================================================================
# n_classes = 2   # Classificação binária: Benign vs Malicious
# n_classes = 8   # Classificação agrupada
# n_classes = 34  # Classificação multiclasse completa
#=================================================================

n_frac = 0.05 #Define a fração do dataset que será utilizada(2%)
n_trials_tpe = 10 #Define o número de tentativas de otimização
plot_param_importances = False #Define se será gerado um gráfico mostrando a importância dos hiperparâmetros
timeout_tpe = 600 #Define o tempo máximo para a otimização TPE
random_state = 42 #Define a semente aleatória do experimento
n_jobs = -1 #Define que o código poderá usar todos os núcleos disponíveis da CPU

TEST_SIZE = 0.20 #Define o tamanho de amostras de teste

# %%
# ============================================================
# 2. Carregar arquivos CSV
# ============================================================

csv_files = glob.glob(os.path.join(DATASET_DIR, "*.csv"))

if len(csv_files) == 0:
    raise FileNotFoundError(f"Nenhum arquivo CSV encontrado em: {DATASET_DIR}")

print(f"Quantidade de arquivos CSV encontrados: {len(csv_files)}")


lista_dfs = []

for file in csv_files:
    print(f"Lendo arquivo: {os.path.basename(file)}")
    
    df_temp = pd.read_csv(file, low_memory=False)
    
    # Usa apenas uma fração do arquivo para teste rápido
    if n_frac < 1.0:
        df_temp = df_temp.sample(frac=n_frac, random_state=random_state)
    
    lista_dfs.append(df_temp)

df = pd.concat(lista_dfs, ignore_index=True)

print("\nDataset carregado com sucesso.")
print("Dimensão inicial:", df.shape)
# Out:
# Quantidade de arquivos CSV encontrados: 85
# Lendo arquivo: Backdoor_Malware.pcap.csv
# Lendo arquivo: BenignTraffic.pcap.csv
# Lendo arquivo: BenignTraffic1.pcap.csv
# Lendo arquivo: BenignTraffic2.pcap.csv
# Lendo arquivo: BenignTraffic3.pcap.csv
# Lendo arquivo: DoS-UDP_Flood.pcap.csv
# Lendo arquivo: DoS-UDP_Flood1.pcap.csv
# Lendo arquivo: DoS-UDP_Flood10.pcap.csv
# Lendo arquivo: DoS-UDP_Flood11.pcap.csv
# Lendo arquivo: DoS-UDP_Flood12.pcap.csv
# Lendo arquivo: DoS-UDP_Flood13.pcap.csv
# Lendo arquivo: DoS-UDP_Flood14.pcap.csv
# Lendo arquivo: DoS-UDP_Flood15.pcap.csv
# Lendo arquivo: DoS-UDP_Flood16.pcap.csv
# Lendo arquivo: DoS-UDP_Flood2.pcap.csv
# Lendo arquivo: DoS-UDP_Flood3.pcap.csv
# Lendo arquivo: DoS-UDP_Flood4.pcap.csv
# Lendo arquivo: DoS-UDP_Flood5.pcap.csv
# Lendo arquivo: DoS-UDP_Flood6.pcap.csv
# Lendo arquivo: DoS-UDP_Flood7.pcap.csv
# Lendo arquivo: DoS-UDP_Flood8.pcap.csv
# Lendo arquivo: DoS-UDP_Flood9.pcap.csv
# Lendo arquivo: Merged01.csv
# Lendo arquivo: Merged02.csv
# Lendo arquivo: Merged03.csv
# Lendo arquivo: Merged04.csv
# Lendo arquivo: Merged05.csv
# Lendo arquivo: Merged06.csv
# Lendo arquivo: Merged07.csv
# Lendo arquivo: Merged08.csv
# Lendo arquivo: Merged09.csv
# Lendo arquivo: Merged10.csv
# Lendo arquivo: Merged11.csv
# Lendo arquivo: Merged12.csv
# Lendo arquivo: Merged13.csv
# Lendo arquivo: Merged14.csv
# Lendo arquivo: Merged15.csv
# Lendo arquivo: Merged16.csv
# Lendo arquivo: Merged17.csv
# Lendo arquivo: Merged18.csv
# Lendo arquivo: Merged19.csv
# Lendo arquivo: Merged20.csv
# Lendo arquivo: Merged21.csv
# Lendo arquivo: Merged22.csv
# Lendo arquivo: Merged23.csv
# Lendo arquivo: Merged24.csv
# Lendo arquivo: Merged25.csv
# Lendo arquivo: Merged26.csv
# Lendo arquivo: Merged27.csv
# Lendo arquivo: Merged28.csv
# Lendo arquivo: Merged29.csv
# Lendo arquivo: Merged30.csv
# Lendo arquivo: Merged31.csv
# Lendo arquivo: Merged32.csv
# Lendo arquivo: Merged33.csv
# Lendo arquivo: Merged34.csv
# Lendo arquivo: Merged35.csv
# Lendo arquivo: Merged36.csv
# Lendo arquivo: Merged37.csv
# Lendo arquivo: Merged38.csv
# Lendo arquivo: Merged39.csv
# Lendo arquivo: Merged40.csv
# Lendo arquivo: Merged41.csv
# Lendo arquivo: Merged42.csv
# Lendo arquivo: Merged43.csv
# Lendo arquivo: Merged44.csv
# Lendo arquivo: Merged45.csv
# Lendo arquivo: Merged46.csv
# Lendo arquivo: Merged47.csv
# Lendo arquivo: Merged48.csv
# Lendo arquivo: Merged49.csv
# Lendo arquivo: Merged50.csv
# Lendo arquivo: Merged51.csv
# Lendo arquivo: Merged52.csv
# Lendo arquivo: Merged53.csv
# Lendo arquivo: Merged54.csv
# Lendo arquivo: Merged55.csv
# Lendo arquivo: Merged56.csv
# Lendo arquivo: Merged57.csv
# Lendo arquivo: Merged58.csv
# Lendo arquivo: Merged59.csv
# Lendo arquivo: Merged60.csv
# Lendo arquivo: Merged61.csv
# Lendo arquivo: Merged62.csv
# Lendo arquivo: Merged63.csv
#
# Dataset carregado com sucesso.
# Dimensão inicial: (2459683, 40)

# %%
# ============================================================
# 3. Detectar coluna de rótulo
# ============================================================

target_candidates = [
    "label", "Label", "Attack", "attack",
    "class", "Class", "Category", "category"
]

LABEL_COL = None

for col in target_candidates:
    if col in df.columns:
        LABEL_COL = col
        break

if LABEL_COL is None:
    raise ValueError(
        "Não foi possível detectar a coluna de rótulo. "
        "Verifique se existe uma coluna chamada label, Label, Attack, class etc."
    )

print(f"\nColuna de rótulo detectada: {LABEL_COL}")
# Out:
# Coluna de rótulo detectada: Label

# %%
# ============================================================
# 4. Limpeza básica do dataset
# ============================================================

# Remove espaços extras nos nomes das colunas
df.columns = df.columns.str.strip()

# Remove linhas com rótulo vazio
df = df.dropna(subset=[LABEL_COL])

# Converte infinitos para NaN
df = df.replace([np.inf, -np.inf], np.nan)

# Remove linhas com NaN
df = df.dropna()

print("\nDimensão após limpeza:", df.shape)
# Out:
# Dimensão após limpeza: (2250925, 40)

# %%
# ============================================================
# 5. Ajustar o problema para n_classes
# ============================================================
#=======================================================================
# Conta amostras por classe
#class_counts = df[LABEL_COL].value_counts()
#
# Mantém apenas classes com amostras mínimas
#valid_classes = class_counts[class_counts >= min_samples_per_class].index
#
#df = df[df[LABEL_COL].isin(valid_classes)].copy()
#
# Seleciona as n_classes mais frequentes
#top_classes = df[LABEL_COL].value_counts().head(n_classes).index
#
#df = df[df[LABEL_COL].isin(top_classes)].copy()
#
#print("\nClasses selecionadas:")
#print(df[LABEL_COL].value_counts())
#==============================================================================




# ============================================================
# 5. Criar classificação binária real: Benign vs Malicious
# ============================================================

# Guarda o nome da coluna original de rótulo
ORIGINAL_LABEL_COL = LABEL_COL

# Remove espaços extras nos valores da coluna de rótulo
df[ORIGINAL_LABEL_COL] = df[ORIGINAL_LABEL_COL].astype(str).str.strip()

# Verificar quais classes existem antes da transformação binária
print("Classes originais encontradas no dataset:")
print(df[ORIGINAL_LABEL_COL].value_counts().head(20))

# Cria uma nova coluna binária:
# Benign serão tratados como tráfego normal
# Todas as demais classes serão tratadas como ataque (Maliciosas)
df["label_binary"] = df[ORIGINAL_LABEL_COL].apply(
    lambda x: "Benign" if x.lower() in ["benigntraffic", "benign", "benign_traffic"] else "Malicious"
)

# Remove a coluna original de rótulo para evitar vazamento de informação
df = df.drop(columns=[ORIGINAL_LABEL_COL])

# Atualizar a coluna de rótulo para o AutoGluon
LABEL_COL = "label_binary"

# Exibe a distribuição das classes binárias
print("\nDistribuição da classificação binária:")
print(df[LABEL_COL].value_counts())

# Validação obrigatória
if df[LABEL_COL].nunique() != 2:
    raise ValueError(
        "Erro: o dataset não possui as duas classes Benign e Malicious. "
        "Verifique se existe BenignTraffic nos arquivos carregados."
    )
# Out:
# Classes originais encontradas no dataset:
# Label
# DDOS-ICMP_FLOOD            345426
# DDOS-UDP_FLOOD             259100
# DDOS-TCP_FLOOD             214675
# DDOS-PSHACK_FLOOD          196168
# DDOS-SYN_FLOOD             194212
# DDOS-RSTFINFLOOD           193558
# DDOS-SYNONYMOUSIP_FLOOD    171674
# DOS-UDP_FLOOD              158659
# DOS-TCP_FLOOD              127960
# DOS-SYN_FLOOD               96911
# BENIGN                      52634
# MIRAI-GREETH_FLOOD          47405
# MIRAI-UDPPLAIN              42567
# MIRAI-GREIP_FLOOD           36443
# DDOS-ICMP_FRAGMENTATION     21912
# VULNERABILITYSCAN           17878
# MITM-ARPSPOOFING            14797
# DDOS-ACK_FRAGMENTATION      13804
# DDOS-UDP_FRAGMENTATION      13673
# DNS_SPOOFING                 8566
# Name: count, dtype: int64
#
# Distribuição da classificação binária:
# label_binary
# Malicious    2198291
# Benign         52634
# Name: count, dtype: int64

# %%
# ============================================================
# 6. Separar treino e teste
# ============================================================

train_data, test_data = train_test_split(
    df,
    test_size=TEST_SIZE,
    random_state=random_state,
    stratify=df[LABEL_COL]
)

print("\nTamanho do treino:", train_data.shape)
print("Tamanho do teste :", test_data.shape)

print("\nDistribuição das classes no treino:")
print(train_data[LABEL_COL].value_counts())

print("\nDistribuição das classes no teste:")
print(test_data[LABEL_COL].value_counts())
train_data.head()
# Out:
# Tamanho do treino: (1800740, 40)
# Tamanho do teste : (450185, 40)
#
# Distribuição das classes no treino:
# label_binary
# Malicious    1758633
# Benign         42107
# Name: count, dtype: int64
#
# Distribuição das classes no teste:
# label_binary
# Malicious    439658
# Benign        10527
# Name: count, dtype: int64
#          Header_Length  Protocol Type  Time_To_Live          Rate  \
# 1301289           20.0              6         64.00  21354.839367
# 1402079            0.0              1         64.00  53444.240571
# 1634288            0.0              1         63.36  17497.409370
# 716072            20.0              6         64.00  24813.962019
# 1172190            8.0             17         64.00  17173.582279
#
#          fin_flag_number  syn_flag_number  rst_flag_number  psh_flag_number  \
# 1301289              1.0              0.0              1.0              0.0
# 1402079              0.0              0.0              0.0              0.0
# 1634288              0.0              0.0              0.0              0.0
# 716072               0.0              1.0              0.0              0.0
# 1172190              0.0              0.0              0.0              0.0
#
#          ack_flag_number  ece_flag_number  ...  Tot sum   Min   Max   AVG  \
# 1301289              0.0              0.0  ...   6000.0  60.0  60.0  60.0
# 1402079              0.0              0.0  ...   6000.0  60.0  60.0  60.0
# 1634288              0.0              0.0  ...   6000.0  60.0  60.0  60.0
# 716072               0.0              0.0  ...   6000.0  60.0  60.0  60.0
# 1172190              0.0              0.0  ...   6000.0  60.0  60.0  60.0
#
#          Std  Tot size       IAT  Number  Variance  label_binary
# 1301289  0.0      60.0  0.000047   100.0       0.0     Malicious
# 1402079  0.0      60.0  0.000019   100.0       0.0     Malicious
# 1634288  0.0      60.0  0.000057   100.0       0.0     Malicious
# 716072   0.0      60.0  0.000040   100.0       0.0     Malicious
# 1172190  0.0      60.0  0.000058   100.0       0.0     Malicious
#
# [5 rows x 40 columns]

# %%
# ============================================================
# 7. Configurar AutoGluon
# ============================================================

if device == "cpu":
    num_gpus = 0
else:
    num_gpus = "auto"

if n_jobs == -1:
    num_cpus = "auto"
else:
    num_cpus = n_jobs

# ------------------------------------------------------------
# Definir se o AutoGluon usará somente XGBoost ou vários modelos
# ------------------------------------------------------------

USE_ONLY_XGBOOST = True

if USE_ONLY_XGBOOST:
    # Usa apenas o modelo XGBoost dentro do AutoGluon
    hyperparameters = {
        "XGB": {}
    }
else:
    # Usa vários modelos automáticos do AutoGluon
    hyperparameters = {
        "GBM": {}, #Gradient Boosting Machine
        "XGB": {}, #XGBoost
        "RF": {}, #Random Forest
        "XT": {}, #Extra Trees
        "CAT": {}, #CatBoost
        "NN_TORCH": {}, #Rede Neural usando PyTorch
      
    }

# HPO: número de tentativas de otimização
hyperparameter_tune_kwargs = {
    "num_trials": n_trials_tpe,
    "scheduler": "local",
    "searcher": "auto"
}

print(f"CPUs utilizadas: {num_cpus}")
print(f"GPUs utilizadas: {num_gpus}")
# Out:
# CPUs utilizadas: auto
# GPUs utilizadas: 0

# %%
# ============================================================
# 8. Treinar modelo com AutoGluon - Classificação Binária
# ============================================================

predictor = TabularPredictor(
    label=LABEL_COL,
    problem_type="binary",
    eval_metric="f1",
    path=RESULTS_DIR,
    learner_kwargs={
        "label_count_threshold": min_samples_per_class
    }
)

predictor.fit(
    train_data=train_data,
    time_limit=timeout_tpe,
    presets="medium_quality",
    hyperparameters=hyperparameters,
    hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
    num_cpus=num_cpus,
    num_gpus=num_gpus
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="C:\Dataset\Resultados\AutoGluon"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.13.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26200
# CPU Count:          8
# Pytorch Version:    2.9.1+cpu
# CUDA Version:       CUDA is not available
# Memory Avail:       5.49 GB / 15.88 GB (34.6%)
# Disk Space Avail:   230.85 GB / 930.66 GB (24.8%)
# ===================================================
# Presets specified: ['medium_quality']
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "C:\Dataset\Resultados\AutoGluon"
# Train Data Rows:    1800740
# Train Data Columns: 39
# Label Column:       label_binary
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = Malicious, class 0 = Benign
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Malicious) vs negative (Benign) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5712.91 MB
# 	Train Data (Original)  Memory Usage: 535.80 MB (9.4% of available memory)
# 	Warning: Data size prior to feature transformation consumes 9.4% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 2): ['LLC', 'Tot size']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 2 | ['LLC', 'Tot size']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['Header_Length', 'Time_To_Live', 'Rate', 'fin_flag_number', 'syn_flag_number', ...]
# 		('int', [])   :  1 | ['Protocol Type']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['Header_Length', 'Time_To_Live', 'Rate', 'fin_flag_number', 'syn_flag_number', ...]
# 		('int', [])   :  1 | ['Protocol Type']
# 	6.7s = Fit runtime
# 	37 features in original data used to generate 37 features in processed data.
# 	Train Data (Processed) Memory Usage: 508.33 MB (8.7% of available memory)
# Data preprocessing and feature engineering runtime = 7.78s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.02, Train Rows: 1764725, Val Rows: 36015
# User-specified model hyperparameters to be fit:
# {
# 	'XGB': [{}],
# }
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Hyperparameter tuning model: XGBoost ... Tuning model for up to 533.0s of the 592.22s of remaining time.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.766 GB out of 4.637 GB available memory (81.233%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.13 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
#   0%|          | 0/10 [00:00<?, ?it/s]
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.766 GB out of 4.373 GB available memory (86.127%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.20 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.766 GB out of 4.845 GB available memory (77.731%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.09 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.809 GB out of 4.735 GB available memory (80.441%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.12 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.764 GB out of 4.666 GB available memory (80.665%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.13 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.865 GB out of 4.606 GB available memory (83.906%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.17 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.764 GB out of 4.613 GB available memory (81.585%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.14 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.809 GB out of 4.587 GB available memory (83.036%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.16 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.766 GB out of 4.648 GB available memory (81.034%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.13 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.765 GB out of 4.654 GB available memory (80.889%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.13 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 3.765 GB out of 4.646 GB available memory (81.041%)... (100.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.13 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# Fitted model: XGBoost\T1 ...
# 	0.9956	 = Validation score   (f1)
# 	35.85s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitted model: XGBoost\T2 ...
# 	0.9958	 = Validation score   (f1)
# 	39.19s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitted model: XGBoost\T3 ...
# 	0.9882	 = Validation score   (f1)
# 	6.52s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitted model: XGBoost\T4 ...
# 	0.9937	 = Validation score   (f1)
# 	4.77s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitted model: XGBoost\T5 ...
# 	0.9957	 = Validation score   (f1)
# 	10.86s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitted model: XGBoost\T6 ...
# 	0.9959	 = Validation score   (f1)
# 	102.86s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitted model: XGBoost\T7 ...
# 	0.9882	 = Validation score   (f1)
# 	4.92s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitted model: XGBoost\T8 ...
# 	0.9951	 = Validation score   (f1)
# 	6.27s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitted model: XGBoost\T9 ...
# 	0.9951	 = Validation score   (f1)
# 	6.76s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitted model: XGBoost\T10 ...
# 	0.996	 = Validation score   (f1)
# 	71.29s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 268.85s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=8, gpus=0, mem=0.0/6.1 GB
# 	Ensemble Weights: {'XGBoost\T10': 1.0}
# 	0.996	 = Validation score   (f1)
# 	1.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 359.41s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 200223.6 rows/s (36015 batch size)
# Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# Calibrating decision threshold to optimize metric f1 | Checking 51 thresholds...
# Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# 	Base Threshold: 0.500	| val: 0.9960
# 	Best Threshold: 0.500	| val: 0.9960
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("C:\Dataset\Resultados\AutoGluon")

# %%
# ============================================================
# 9. Leaderboard dos modelos
# ============================================================

# Gera a tabela de classificação dos modelos treinados
leaderboard = predictor.leaderboard(test_data, silent=True)

print("\n====================================================")
print("LEADERBOARD - AUTOGLUON")
print("====================================================")
print(leaderboard)

leaderboard_path = os.path.join(RESULTS_DIR, "leaderboard_autogluon.csv")
leaderboard.to_csv(leaderboard_path, index=False)

print(f"\nLeaderboard salvo em: {leaderboard_path}")
# Out:
# ====================================================
# LEADERBOARD - AUTOGLUON
# ====================================================
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0           XGBoost\T10    0.996292   0.995963          f1        2.090015
# 1   WeightedEnsemble_L2    0.996292   0.995963          f1        2.104552
# 2            XGBoost\T6    0.996254   0.995934          f1        2.195368
# 3            XGBoost\T1    0.996218   0.995650          f1        1.122144
# 4            XGBoost\T2    0.996215   0.995835          f1        1.378039
# 5            XGBoost\T5    0.996102   0.995736          f1        0.617109
# 6            XGBoost\T8    0.995494   0.995087          f1        0.487097
# 7            XGBoost\T9    0.995484   0.995113          f1        0.482106
# 8            XGBoost\T4    0.993960   0.993736          f1        0.431986
# 9            XGBoost\T7    0.988170   0.988172          f1        0.433957
# 10           XGBoost\T3    0.988170   0.988172          f1        0.437569
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.175199   71.292387                 2.090015
# 1        0.179874   72.342892                 0.014536
# 2        0.182255  102.859445                 2.195368
# 3        0.248543   35.850740                 1.122144
# 4        0.147784   39.188777                 1.378039
# 5        0.059575   10.862071                 0.617109
# 6        0.041461    6.273979                 0.487097
# 7        0.041301    6.762112                 0.482106
# 8        0.044541    4.773353                 0.431986
# 9        0.038097    4.915227                 0.433957
# 10       0.046616    6.517008                 0.437569
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.175199          71.292387            1       True
# 1                 0.004675           1.050505            2       True
# 2                 0.182255         102.859445            1       True
# 3                 0.248543          35.850740            1       True
# 4                 0.147784          39.188777            1       True
# 5                 0.059575          10.862071            1       True
# 6                 0.041461           6.273979            1       True
# 7                 0.041301           6.762112            1       True
# 8                 0.044541           4.773353            1       True
# 9                 0.038097           4.915227            1       True
# 10                0.046616           6.517008            1       True
#
#     fit_order
# 0          10
# 1          11
# 2           6
# 3           1
# 4           2
# 5           5
# 6           8
# 7           9
# 8           4
# 9           7
# 10          3
#
# Leaderboard salvo em: C:\Dataset\Resultados\AutoGluon\leaderboard_autogluon.csv

# %%
# ============================================================
# 10. Predição no conjunto de teste
# ============================================================

X_test = test_data.drop(columns=[LABEL_COL])
y_test = test_data[LABEL_COL]

y_pred = predictor.predict(X_test)

y_pred.head()
# Out:
# 1943325    Malicious
# 561369     Malicious
# 368764     Malicious
# 2305271    Malicious
# 470212     Malicious
# Name: label_binary, dtype: object

# %%
# ============================================================
# 11. Métricas de avaliação
# ============================================================

accuracy = accuracy_score(y_test, y_pred)
balanced_acc = balanced_accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average="weighted", zero_division=0)
recall = recall_score(y_test, y_pred, average="weighted", zero_division=0)
f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)

print("\n====================================================")
print("RESULTADOS - AUTOGLUON")
print("====================================================")
print(f"Accuracy          : {accuracy:.6f}")
print(f"Balanced Accuracy : {balanced_acc:.6f}")
print(f"Precision         : {precision:.6f}")
print(f"Recall            : {recall:.6f}")
print(f"F1-score          : {f1:.6f}")

print("\nRelatório de classificação:")
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# ====================================================
# RESULTADOS - AUTOGLUON
# ====================================================
# Accuracy          : 0.992761
# Balanced Accuracy : 0.931390
# Precision         : 0.992930
# Recall            : 0.992761
# F1-score          : 0.992836
#
# Relatório de classificação:
#               precision    recall  f1-score   support
#
#       Benign       0.83      0.87      0.85     10527
#    Malicious       1.00      1.00      1.00    439658
#
#     accuracy                           0.99    450185
#    macro avg       0.91      0.93      0.92    450185
# weighted avg       0.99      0.99      0.99    450185

# %%
# Salvar relatório em TXT
report_path = os.path.join(RESULTS_DIR, "classification_report_autogluon.txt")

with open(report_path, "w", encoding="utf-8") as f:
    f.write("RESULTADOS - AUTOGLUON\n")
    f.write("====================================================\n")
    f.write(f"Accuracy          : {accuracy:.6f}\n")
    f.write(f"Balanced Accuracy : {balanced_acc:.6f}\n")
    f.write(f"Precision         : {precision:.6f}\n")
    f.write(f"Recall            : {recall:.6f}\n")
    f.write(f"F1-score          : {f1:.6f}\n\n")
    f.write("Relatório de classificação:\n")
    f.write(classification_report(y_test, y_pred, zero_division=0))

print(f"\nRelatório salvo em: {report_path}")
# Out:
# Relatório salvo em: C:\Dataset\Resultados\AutoGluon\classification_report_autogluon.txt

# %%
# ============================================================
# 12. Matriz de confusão
# ============================================================

classes = sorted(y_test.unique())

cm = confusion_matrix(y_test, y_pred, labels=classes)

plt.figure(figsize=(10, 8))

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=classes
)

disp.plot(
    cmap="GnBu",
    xticks_rotation=90,
        values_format="d"
    
)

plt.title("Matriz de Confusão - AutoGluon")
plt.tight_layout()

cm_path = os.path.join(RESULTS_DIR, "matriz_confusao_autogluon.png")
plt.savefig(cm_path, dpi=300, bbox_inches="tight")
plt.show()

print(f"Matriz de confusão salva em: {cm_path}")
# Out:
# Matriz de confusão salva em: C:\Dataset\Resultados\AutoGluon\matriz_confusao_autogluon.png
